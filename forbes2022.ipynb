# %% [markdown]
# <a href="https://colab.research.google.com/github/iamabhi9v/Forbes_2022_Billionaires/blob/main/forbes2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/forbes2022"

# %%
import pandas as pd

# %%
fb = pd.read_csv('/content/gdrive/My Drive/forbes2022/forbes_2022_billionaires.csv')

# %%
fb.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %%
fb.shape
# Out:
# (2668, 22)

# %%
fb.dtypes
# Out:
# rank                      int64
# personName               object
# age                     float64
# finalWorth              float64
# year                      int64
# month                     int64
# category                 object
# source                   object
# country                  object
# state                    object
# city                     object
# countryOfCitizenship     object
# organization             object
# selfMade                   bool
# gender                   object
# birthDate                object
# title                    object
# philanthropyScore       float64
# residenceMsa             object
# numberOfSiblings        float64
# bio                      object
# about                    object
# dtype: object

# %%
fb.describe()
# Out:
#               rank          age     finalWorth    year   month  \
# count  2668.000000  2582.000000    2668.000000  2668.0  2668.0
# mean   1302.919040    64.210689    4762.350075  2022.0     4.0
# std     747.807782    13.401258   10540.482258     0.0     0.0
# min       1.000000    19.000000    1000.000000  2022.0     4.0
# 25%     665.000000    55.000000    1500.000000  2022.0     4.0
# 50%    1292.000000    64.000000    2400.000000  2022.0     4.0
# 75%    1929.000000    74.000000    4300.000000  2022.0     4.0
# max    2578.000000   100.000000  219000.000000  2022.0     4.0
#
#        philanthropyScore  numberOfSiblings
# count         396.000000        127.000000
# mean            1.856061          2.732283
# std             0.971486          1.891706
# min             1.000000          1.000000
# 25%             1.000000          2.000000
# 50%             2.000000          2.000000
# 75%             2.000000          3.000000
# max             5.000000         14.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fb.plot.hist()

# %%
fb.plot.box()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
fb['city'].value_counts()
# Out:
# New York        106
# Beijing          83
# Hong Kong        68
# London           64
# Shanghai         61
#                ...
# Xinxiang          1
# Sioux Falls       1
# Scottsdale        1
# Newbury Park      1
# Pottsville        1
# Name: city, Length: 749, dtype: int64

# %%
fb['category'].value_counts()/len(fb['category'])*100
# Out:
# Finance & Investments         14.692654
# Technology                    12.856072
# Manufacturing                 12.631184
# Fashion & Retail               9.370315
# Healthcare                     8.133433
# Food & Beverage                7.608696
# Real Estate                    7.233883
# Diversified                    6.746627
# Media & Entertainment          3.710645
# Energy                         3.560720
# Automotive                     2.623688
# Metals & Mining                2.548726
# Service                        1.986507
# Construction & Engineering     1.724138
# Telecom                        1.386807
# Logistics                      1.311844
# Sports                         1.011994
# Gambling & Casinos             0.862069
# Name: category, dtype: float64

# %%
fb['category'].value_counts().plot.bar()

# %%
fb.plot.scatter('finalWorth','year')

# %%
pd.crosstab(fb['source'],fb['state'])
# Out:
# state                     Arizona  Arkansas  California  Colorado  \
# source
# AOL                             0         0           0         0
# Airbnb                          0         0           3         0
# Amazon                          0         0           0         0
# Apple                           0         0           1         0
# Apple, Disney                   0         0           1         0
# ...                           ...       ...         ...       ...
# video games                     0         0           0         0
# videogames                      0         0           0         0
# vodka                           0         0           0         0
# web hosting                     1         0           0         0
# wireless networking gear        0         0           1         0
#
# state                     Connecticut  Florida  Georgia  Hawaii  Idaho  \
# source
# AOL                                 0        0        0       0      0
# ...

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(pd.crosstab(fb['age'],fb['finalWorth']))
# Out:
# (17538.56276759101,
#  3.515422179425705e-05,
#  16800,
#  array([[0.0348567 , 0.04492641, 0.04725019, ..., 0.0003873 , 0.0003873 ,
#          0.0003873 ],
#         [0.1045701 , 0.13477924, 0.14175058, ..., 0.00116189, 0.00116189,
#          0.00116189],
#         [0.0697134 , 0.08985283, 0.09450039, ..., 0.00077459, 0.00077459,
#          0.00077459],
#         ...,
#         [0.1045701 , 0.13477924, 0.14175058, ..., 0.00116189, 0.00116189,
#          0.00116189],
#         [0.1045701 , 0.13477924, 0.14175058, ..., 0.00116189, 0.00116189,
#          0.00116189],
#         [0.0348567 , 0.04492641, 0.04725019, ..., 0.0003873 , 0.0003873 ,
#          0.0003873 ]]))

# %%
fb.groupby('finalWorth')['age'].mean()
# Out:
# finalWorth
# 1000.0      62.677778
# 1100.0      61.327586
# 1200.0      61.016393
# 1300.0      61.446970
# 1400.0      61.889908
#               ...
# 118000.0    91.000000
# 129000.0    66.000000
# 158000.0    73.000000
# 171000.0    58.000000
# 219000.0    50.000000
# Name: age, Length: 228, dtype: float64

# %%
fb.groupby('age')['rank'].mean().plot.bar()

# %%
fb.corr()
# Out:
#                        rank       age  finalWorth  year  month  selfMade  \
# rank               1.000000 -0.129878   -0.437261   NaN    NaN  0.065436
# age               -0.129878  1.000000    0.041423   NaN    NaN -0.086010
# finalWorth        -0.437261  0.041423    1.000000   NaN    NaN -0.022941
# year                    NaN       NaN         NaN   NaN    NaN       NaN
# month                   NaN       NaN         NaN   NaN    NaN       NaN
# selfMade           0.065436 -0.086010   -0.022941   NaN    NaN  1.000000
# philanthropyScore  0.043902  0.221939    0.020995   NaN    NaN  0.059796
# numberOfSiblings  -0.096931  0.268062    0.153465   NaN    NaN  0.232797
#
#                    philanthropyScore  numberOfSiblings
# rank                        0.043902         -0.096931
# age                         0.221939          0.268062
# finalWorth                  0.020995          0.153465
# year                             NaN               NaN
# ...

# %%
fb.isnull()
# Out:
#        rank  personName    age  finalWorth   year  month  category  source  \
# 0     False       False  False       False  False  False     False   False
# 1     False       False  False       False  False  False     False   False
# 2     False       False  False       False  False  False     False   False
# 3     False       False  False       False  False  False     False   False
# 4     False       False  False       False  False  False     False   False
# ...     ...         ...    ...         ...    ...    ...       ...     ...
# 2663  False       False  False       False  False  False     False   False
# 2664  False       False  False       False  False  False     False   False
# 2665  False       False  False       False  False  False     False   False
# 2666  False       False  False       False  False  False     False   False
# 2667  False       False  False       False  False  False     False   False
#
# ...

# %%
fb.isnull().sum()
# Out:
# rank                       0
# personName                 0
# age                       86
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# country                   13
# state                   1920
# city                      44
# countryOfCitizenship       0
# organization            2316
# selfMade                   0
# gender                    16
# birthDate                 99
# title                   2267
# philanthropyScore       2272
# residenceMsa            2029
# numberOfSiblings        2541
# bio                        0
# about                   1106
# dtype: int64

# %%
fb.isnull().shape
# Out:
# (2668, 22)

# %%
fb['finalWorth'].fillna(1)
# Out:
# 0       219000.0
# 1       171000.0
# 2       158000.0
# 3       129000.0
# 4       118000.0
#           ...
# 2663      1000.0
# 2664      1000.0
# 2665      1000.0
# 2666      1000.0
# 2667      1000.0
# Name: finalWorth, Length: 2668, dtype: float64

# %%
fb.dropna()
# Out:
#       rank             personName   age  finalWorth  year  month  \
# 37      37     Stephen Schwarzman  75.0     34800.0  2022      4
# 146    146             John Doerr  70.0     12700.0  2022      4
# 258    254           Steven Rales  71.0      8400.0  2022      4
# 384    375  Randa Duncan Williams  60.0      6600.0  2022      4
# 1304  1292            John Fisher  60.0      2400.0  2022      4
#
#                    category                      source        country  \
# 37    Finance & Investments                 investments  United States
# 146              Technology             venture capital  United States
# 258           Manufacturing  manufacturing, investments  United States
# 384                  Energy                   pipelines  United States
# 1304       Fashion & Retail                         Gap  United States
#
#            state  ...            organization selfMade gender   birthDate  \
# ...

# %%
fb.dropna().shape
# Out:
# (5, 22)

# %%
fb.dropna(how='all')
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
fb.dropna(how='all').shape
# Out:
# (2668, 22)

# %%
import numpy as np

# %%
fb['finalWorth'].plot.box()

# %%
import seaborn as sns

# %%
fb.corr()
# Out:
#                        rank       age  finalWorth  year  month  selfMade  \
# rank               1.000000 -0.129878   -0.437261   NaN    NaN  0.065436
# age               -0.129878  1.000000    0.041423   NaN    NaN -0.086010
# finalWorth        -0.437261  0.041423    1.000000   NaN    NaN -0.022941
# year                    NaN       NaN         NaN   NaN    NaN       NaN
# month                   NaN       NaN         NaN   NaN    NaN       NaN
# selfMade           0.065436 -0.086010   -0.022941   NaN    NaN  1.000000
# philanthropyScore  0.043902  0.221939    0.020995   NaN    NaN  0.059796
# numberOfSiblings  -0.096931  0.268062    0.153465   NaN    NaN  0.232797
#
#                    philanthropyScore  numberOfSiblings
# rank                        0.043902         -0.096931
# age                         0.221939          0.268062
# finalWorth                  0.020995          0.153465
# year                             NaN               NaN
# ...

# %%
cor = fb.corr()
plt.figure(figsize=(12,6))
sns.heatmap(cor)
